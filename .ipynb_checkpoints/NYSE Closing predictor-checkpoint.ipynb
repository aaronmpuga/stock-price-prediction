# %% [markdown]
# # Stock Price Prediction for Apple Inc.
#
# ## Introduction
#
# This notebook demonstrates the process of predicting Apple's closing stock price using historical data from approx. 2010-2016
#
# ---
#
# ## Setup and Installation
#
# ```python
# # Install required libraries
# !pip install pandas scikit-learn seaborn
# ````
# ### Author: Aaron Mpuga

# %%
import pandas as pd
import os
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.linear_model import Ridge

# %% [markdown]
# ## Data Loading

# %%
#Path to where I've saved the downloaded csv files from Kaggle
folder_dir = "/Users/atwoo/Documents/Personal_Projects/NYSE/stock-price-prediction/data"

company_fundamentals = pd.read_csv(os.path.join(folder_dir, "fundamentals.csv"))
company_prices = pd.read_csv(os.path.join(folder_dir, "prices.csv"))
company_split_prices = pd.read_csv(os.path.join(folder_dir, "prices-split-adjusted.csv"))
company_info = pd.read_csv(os.path.join(folder_dir, "securities.csv"))

# %% [markdown]
# ## Data Preparation
#
# In this section, the dataset is filtered to only include data for Apple Inc. (Ticker Symbol: AAPL).
#
# To analyze data for another company, you can replace `"AAPL"` with the ticker symbol of a different company in the code cell below:
#
# ```python
# # These are the lines that you'd have to change in the following code cell
# apple_fund = company_fundamentals[company_fundamentals["Ticker Symbol"] == "AAPL"]
# apple_prices = company_prices[company_prices["symbol"] == "AAPL"]

# %%
#Removes the warning in output cell
import warnings
warnings.filterwarnings('ignore')

# %%
#Filter data for Apple Inc.
apple_fund = company_fundamentals[company_fundamentals["Ticker Symbol"]== "AAPL"]
apple_prices = company_prices[company_prices["symbol"] == "AAPL"]

#Convert date columns to datatime for both dataframes
apple_fund.loc[:,"Period Ending"] = pd.to_datetime(apple_fund["Period Ending"])
apple_fund["Year"] = apple_fund["Period Ending"].dt.year
col_idx = apple_fund.columns.get_loc('Period Ending')
apple_fund.insert(col_idx + 1, 'Year', apple_fund.pop('Year'))

apple_prices["date"] = pd.to_datetime(apple_prices["date"])
apple_prices["year"] = apple_prices["date"].dt.year
idx = apple_prices.columns.get_loc("date")
apple_prices.insert(idx + 1, "year", apple_prices.pop("year"))

#Merge the two datasets
apple_df = pd.merge(apple_prices, apple_fund, how='left', left_on=['symbol', 'year'], right_on=['Ticker Symbol', 'Year'])
apple_df = apple_df.drop(["Unnamed: 0", "Ticker Symbol", "Period Ending", "Year", "For Year"], axis=1)
apple_df = apple_df.dropna(axis= 0, how='any')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
#  Simple Moving average:
#  - Caluclated average price of Apple's closing stock after a period of 30 days (average closing price of the 30 rows before the current row)
#  - The first 30 rows of the dataframe are populate with the average value of all closing price values in dataset

# %%
apple_df["SMA_30"] = apple_df["close"].rolling(window=30).mean()
apple_df["SMA_30"].fillna(apple_df["SMA_30"].mean(), inplace= True)
apple_df = apple_df[["date", "year", "symbol", "open", "close", "low", "high", "SMA_30"]]

# %% [markdown]
# ## Data Analysis and Visualization

# %%
#Correlation between the target variable close price and other columns of dataset
apple_corr = apple_df.corr()["close"].sort_values(ascending= False)
apple_corr
# Out:
# close     1.000000
# low       0.999926
# high      0.999924
# open      0.999808
# SMA_30    0.935197
# year     -0.758798
# Name: close, dtype: float64

# %%
sns.lmplot(data= apple_df, x="open", y="close")
sns.lmplot(data= apple_df, x="low", y="close")
sns.lmplot(data= apple_df, x="high", y="close")
sns.lmplot(data= apple_df, x="SMA_30", y="close")

# %% [markdown]
# ## Model Building

# %%
predictors = ["low","SMA_30"]
target = "close"

# %% [markdown]
# Set random state value to an integer for testing/debugging purposes, so that our data is reproducible

# %% [markdown]
# Split data up to where 80% is used to train and 20% will be to test models accuracy.
# - the prediction_train_data is df of just predictors list values after the split so it makes up 80% of the data
# - the target_train_data is a df of  the close values for the matching 80% of the data split for the prediction_train_data

# %%
prediction_train_data, prediction_test_data, target_train_data, target_test_data = train_test_split(apple_df[predictors], apple_df[target], test_size=0.2, random_state=23)

# %% [markdown]
# After looking at the graphs and correlation data I noticed mutlticollinearity between the columns I planned on using as predictors. Therefore, I decided to use a rigid regression model.

# %% [markdown]
# Using GridSearchCV to find the most optimal alpha value that maximizes the models performance
# Quick Explanation:
# - Uses 5 fold method (based on cv value) where 1 alpha value will create the testdata of the rigid model and the remaing 4 alphas will make up the training data for the remaining alphas. This is repeated 4 more times with different alpha values as the test data each time
# - Ultimately this helps to reduce overfitting  by ensuring the model performs well across different subsets of the data.

# %%
ridge = Ridge()
alpha_values = {"alpha" : [0.01,0.1,1,10,100]}
grid_search = GridSearchCV(estimator=ridge,param_grid=alpha_values, cv=5)
grid_search.fit(prediction_train_data, target_train_data)
best_alpha = grid_search.best_params_["alpha"]
ridge_model = Ridge(alpha= best_alpha)
ridge_model.fit(prediction_train_data, target_train_data)
# Out:
# Ridge(alpha=100)

# %% [markdown]
# ## Model Evaluation

# %%
predictions = ridge_model.predict(prediction_test_data)
combined_test_df = prediction_test_data
combined_test_df["Predicted Closing Price"] = predictions
combined_test_df.sort_index(inplace= True)
combined_test_df["Actual Closing Price"] = target_test_data.sort_index()
combined_test_df = combined_test_df.reset_index(drop=True)  # Drop the old index
combined_test_df
# Out:
#             low      SMA_30  Predicted Closing Price  Actual Closing Price
# 0    452.119987  246.371188               456.128670            458.269981
# 1    454.500015  246.371188               458.530229            456.830002
# 2    448.350021  246.371188               452.324598            453.619995
# 3    452.580025  246.371188               456.592869            457.350014
# 4    454.119980  246.371188               458.146756            468.220009
# ..          ...         ...                      ...                   ...
# 197  113.309998  115.059333               114.406251            115.589996
# 198  114.099998  115.023000               115.203440            114.480003
# 199  106.599998  113.480333               107.637384            109.989998
# 200  110.070000  112.140000               111.140336            111.459999
# 201  108.849998  111.415333               109.910140            109.900002
#
# [202 rows x 4 columns]

# %%
#Error Metrics
mse_val = mean_squared_error(combined_test_df["Actual Closing Price"], combined_test_df["Predicted Closing Price"])
mae_val = mean_absolute_error(combined_test_df["Actual Closing Price"], combined_test_df["Predicted Closing Price"])
print(f"Mean square error: {mse_val}\nMean absolute error: {mae_val}")
# Out:
# Mean square error: 6.7549911242569145
# Mean absolute error: 1.5051733610344653

# %% [markdown]
# Using K-fold cross validation error calculations to further see how well the model is performing:
# - The dataset is divided into k equal-sized parts
# - The model is trained k times. Each time, a different fold is used as the test set while the remaining k-1 folds are used as the training data sets
# - In this case I split the data into 5 folds

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=38)
mse_scores = cross_val_score(ridge, prediction_train_data, target_train_data, scoring = "neg_mean_squared_error", cv=kf)
mae_scores = cross_val_score(ridge, prediction_train_data, target_train_data, scoring = "neg_mean_absolute_error",cv=kf)
print(f"Average mean squared error: {-mse_scores.mean()}")
print(f"Average mean absolute error: {-mae_scores.mean()}")
# Out:
# Average mean squared error: 4.984949753486985
# Average mean absolute error: 1.4265143831758595

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The Ridge Regression model was able to predict Apple's closing stock prices effectively. To imporve on this project in the future I could include the addition of more features or use a more advances model.
#
# **Mean Squared Error (MSE):** 6.75
# - The Mean Squared Error in this case indicates that on average the squared difference between the predicted and actual closing prices is about 6.75.
#
# **Mean Absolute Error (MAE):** 1.51
# - The Mean Absolute Error in this case means that on average the model's predictions of the closing price are off by about $1.51. In this context.
#
# **Average Mean Squared Error (MSE):** 4.95
# - During cross-validation, the average MSE of 4.95 indicates that when the data is divided into 5 folds and the model is tested on different subsets, it performs with with a lower level of error.
#
# **Average Mean Absolute Error (MAE):** 1.42
# - The average MAE of 1.42 across the folds shows that the model's predictions are off by approximately $1.42 on average. This reinforces the earlier finding when the model was tested without k-fold validation.
